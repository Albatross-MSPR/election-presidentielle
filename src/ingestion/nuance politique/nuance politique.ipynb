# %%
# Out:
# ...
# 📊 CREATING NUANCE POLITIQUE REFERENCE FILE
# ...
#
# 1️⃣  2017 T1 - Presidential Election First Round
# ----------------------------------------------------------------------------------------------------
#       libelle nuance             signification election
#       ARTHAUD    COM Parti communiste français  2017 T1
#    ASSELINEAU    DIV                    Divers  2017 T1
#     CHEMINADE    DIV                    Divers  2017 T1
# DUPONT-AIGNAN    DLF          Debout la France  2017 T1
#        FILLON     LR          Les Républicains  2017 T1
#         HAMON    SOC          Parti socialiste  2017 T1
#      LASSALLE    MDM        Modem / Démocrates  2017 T1
#        LE PEN     RN    Rassemblement National  2017 T1
#        MACRON    REM   La République en Marche  2017 T1
#     MÉLENCHON     FI       La France insoumise  2017 T1
#        POUTOU    DIV                    Divers  2017 T1
#
#
# 2️⃣  2017 T2 - Presidential Election Runoff
# ...
